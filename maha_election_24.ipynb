# %%
import pandas as pd
col_name = ['Constituency','CandidateName','Party','Result','Votes_Status']
df = pd.read_csv('Data/maha-election-results.csv',delimiter = '|', names = col_name)

# %%
df
# Out:
#      Constituency                                 CandidateName  \
# 0        ACHALPUR                       PRAVIN VASANTRAO TAYADE
# 1        ACHALPUR                                BACCHU B. KADU
# 2        ACHALPUR  ANIRUDHA ALIAS BABALUBHAU SUBHANRAO DESHMUKH
# 3        ACHALPUR                     MANGESH VITTHALRAO BORWAR
# 4        ACHALPUR                        PRADIP SAHEBRAO MANKAR
# ...           ...                                           ...
# 4419        YEVLA                     SHIVLAL POPATRAO DHANWATE
# 4420        YEVLA                      JITENDRA BHASKAR GAIKWAD
# 4421        YEVLA                 BHAGVATRAO BA. SONAWANE-PATIL
# 4422        YEVLA                           AMOL SURESH GAIKWAD
# 4423        YEVLA                                          NOTA
#
#                          Party Result     Votes_Status
# 0       Bharatiya Janata Party    won  78201 (+ 12131)
# 1       Prahar Janshakti Party   lost  66070 ( -12131)
# ...

# %%
df.head(10)
# Out:
#   Constituency                                 CandidateName  \
# 0     ACHALPUR                       PRAVIN VASANTRAO TAYADE
# 1     ACHALPUR                                BACCHU B. KADU
# 2     ACHALPUR  ANIRUDHA ALIAS BABALUBHAU SUBHANRAO DESHMUKH
# 3     ACHALPUR                     MANGESH VITTHALRAO BORWAR
# 4     ACHALPUR                        PRADIP SAHEBRAO MANKAR
# 5     ACHALPUR                                    RAHUL KADU
# 6     ACHALPUR                      RAVI GUNVANTRAO WANKHADE
# 7     ACHALPUR                     GAURAV OMPRAKASH KITUKALE
# 8     ACHALPUR              MOHAMMAD SIDDIQUE MOHAMMAD SADIQ
# 9     ACHALPUR                            MANOJ SURESH MORSE
#
#                             Party Result     Votes_Status
# 0          Bharatiya Janata Party    won  78201 (+ 12131)
# 1          Prahar Janshakti Party   lost  66070 ( -12131)
# 2        Indian National Congress   lost  62791 ( -15410)
# 3                     Independent   lost    560 ( -77641)
# ...

# %% [markdown]
# # Make new columns for votes and margin

# %%
df['Votes_Status']
# Out:
# 0       78201 (+ 12131)
# 1       66070 ( -12131)
# 2       62791 ( -15410)
# 3         560 ( -77641)
# 4         558 ( -77643)
#              ...
# 4419     245 ( -134778)
# 4420     238 ( -134785)
# 4421     237 ( -134786)
# 4422     111 ( -134912)
# 4423    1478 ( -133545)
# Name: Votes_Status, Length: 4424, dtype: object

# %%
ser_1 = df['Votes_Status'].str.split("(")

# %%
ser_1
# Out:
# 0       [78201 , + 12131)]
# 1       [66070 ,  -12131)]
# 2       [62791 ,  -15410)]
# 3         [560 ,  -77641)]
# 4         [558 ,  -77643)]
#                ...
# 4419     [245 ,  -134778)]
# 4420     [238 ,  -134785)]
# 4421     [237 ,  -134786)]
# 4422     [111 ,  -134912)]
# 4423    [1478 ,  -133545)]
# Name: Votes_Status, Length: 4424, dtype: object

# %%
votes = ser_1.apply(lambda x:x[0])
df['Votes'] = votes

# %%
df.head(10)
# Out:
#   Constituency                                 CandidateName  \
# 0     ACHALPUR                       PRAVIN VASANTRAO TAYADE
# 1     ACHALPUR                                BACCHU B. KADU
# 2     ACHALPUR  ANIRUDHA ALIAS BABALUBHAU SUBHANRAO DESHMUKH
# 3     ACHALPUR                     MANGESH VITTHALRAO BORWAR
# 4     ACHALPUR                        PRADIP SAHEBRAO MANKAR
# 5     ACHALPUR                                    RAHUL KADU
# 6     ACHALPUR                      RAVI GUNVANTRAO WANKHADE
# 7     ACHALPUR                     GAURAV OMPRAKASH KITUKALE
# 8     ACHALPUR              MOHAMMAD SIDDIQUE MOHAMMAD SADIQ
# 9     ACHALPUR                            MANOJ SURESH MORSE
#
#                             Party Result     Votes_Status   Votes
# 0          Bharatiya Janata Party    won  78201 (+ 12131)  78201
# 1          Prahar Janshakti Party   lost  66070 ( -12131)  66070
# 2        Indian National Congress   lost  62791 ( -15410)  62791
# ...

# %%
votes_margin = ser_1.apply(lambda x: x[1])
df['Votes_Margin'] = votes_margin

# %%
df.head(5)
# Out:
#   Constituency                                 CandidateName  \
# 0     ACHALPUR                       PRAVIN VASANTRAO TAYADE
# 1     ACHALPUR                                BACCHU B. KADU
# 2     ACHALPUR  ANIRUDHA ALIAS BABALUBHAU SUBHANRAO DESHMUKH
# 3     ACHALPUR                     MANGESH VITTHALRAO BORWAR
# 4     ACHALPUR                        PRADIP SAHEBRAO MANKAR
#
#                       Party Result     Votes_Status   Votes Votes_Margin
# 0    Bharatiya Janata Party    won  78201 (+ 12131)  78201      + 12131)
# 1    Prahar Janshakti Party   lost  66070 ( -12131)  66070       -12131)
# 2  Indian National Congress   lost  62791 ( -15410)  62791       -15410)
# 3               Independent   lost    560 ( -77641)    560       -77641)
# 4  Vanchit Bahujan  Aaghadi   lost    558 ( -77643)    558       -77643)

# %%
df['Votes_Margin'] = df['Votes_Margin'].str.replace(" ","")

# %%
df['Votes_Margin'] = df['Votes_Margin'].str.replace(")","")

# %%
df
# Out:
#      Constituency                                 CandidateName  \
# 0        ACHALPUR                       PRAVIN VASANTRAO TAYADE
# 1        ACHALPUR                                BACCHU B. KADU
# 2        ACHALPUR  ANIRUDHA ALIAS BABALUBHAU SUBHANRAO DESHMUKH
# 3        ACHALPUR                     MANGESH VITTHALRAO BORWAR
# 4        ACHALPUR                        PRADIP SAHEBRAO MANKAR
# ...           ...                                           ...
# 4419        YEVLA                     SHIVLAL POPATRAO DHANWATE
# 4420        YEVLA                      JITENDRA BHASKAR GAIKWAD
# 4421        YEVLA                 BHAGVATRAO BA. SONAWANE-PATIL
# 4422        YEVLA                           AMOL SURESH GAIKWAD
# 4423        YEVLA                                          NOTA
#
#                          Party Result     Votes_Status   Votes Votes_Margin
# 0       Bharatiya Janata Party    won  78201 (+ 12131)  78201        +12131
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Constituency   4424 non-null   object
#  1   CandidateName  4424 non-null   object
#  2   Party          4424 non-null   object
#  3   Result         4136 non-null   object
#  4   Votes_Status   4424 non-null   object
#  5   Votes          4424 non-null   object
#  6   Votes_Margin   4424 non-null   object
# dtypes: object(7)
# memory usage: 242.1+ KB

# %% [markdown]
# # convert votes columns to numeric

# %%
df['Votes'] = df['Votes'].astype(int)
df['Votes_Margin'] = df['Votes_Margin'].astype(int)

# %%
df.head(5)
# Out:
#   Constituency                                 CandidateName  \
# 0     ACHALPUR                       PRAVIN VASANTRAO TAYADE
# 1     ACHALPUR                                BACCHU B. KADU
# 2     ACHALPUR  ANIRUDHA ALIAS BABALUBHAU SUBHANRAO DESHMUKH
# 3     ACHALPUR                     MANGESH VITTHALRAO BORWAR
# 4     ACHALPUR                        PRADIP SAHEBRAO MANKAR
#
#                       Party Result     Votes_Status  Votes  Votes_Margin
# 0    Bharatiya Janata Party    won  78201 (+ 12131)  78201         12131
# 1    Prahar Janshakti Party   lost  66070 ( -12131)  66070        -12131
# 2  Indian National Congress   lost  62791 ( -15410)  62791        -15410
# 3               Independent   lost    560 ( -77641)    560        -77641
# 4  Vanchit Bahujan  Aaghadi   lost    558 ( -77643)    558        -77643

# %%
df
# Out:
#      Constituency                                 CandidateName  \
# 0        ACHALPUR                       PRAVIN VASANTRAO TAYADE
# 1        ACHALPUR                                BACCHU B. KADU
# 2        ACHALPUR  ANIRUDHA ALIAS BABALUBHAU SUBHANRAO DESHMUKH
# 3        ACHALPUR                     MANGESH VITTHALRAO BORWAR
# 4        ACHALPUR                        PRADIP SAHEBRAO MANKAR
# ...           ...                                           ...
# 4419        YEVLA                     SHIVLAL POPATRAO DHANWATE
# 4420        YEVLA                      JITENDRA BHASKAR GAIKWAD
# 4421        YEVLA                 BHAGVATRAO BA. SONAWANE-PATIL
# 4422        YEVLA                           AMOL SURESH GAIKWAD
# 4423        YEVLA                                          NOTA
#
#                          Party Result     Votes_Status  Votes  Votes_Margin
# 0       Bharatiya Janata Party    won  78201 (+ 12131)  78201         12131
# ...

# %%
# Who has got most number of votes

# %%
df.sort_values(by='Votes',ascending=False).head(1)
df.head(5)
# Out:
#   Constituency                                 CandidateName  \
# 0     ACHALPUR                       PRAVIN VASANTRAO TAYADE
# 1     ACHALPUR                                BACCHU B. KADU
# 2     ACHALPUR  ANIRUDHA ALIAS BABALUBHAU SUBHANRAO DESHMUKH
# 3     ACHALPUR                     MANGESH VITTHALRAO BORWAR
# 4     ACHALPUR                        PRADIP SAHEBRAO MANKAR
#
#                       Party Result     Votes_Status  Votes  Votes_Margin
# 0    Bharatiya Janata Party    won  78201 (+ 12131)  78201         12131
# 1    Prahar Janshakti Party   lost  66070 ( -12131)  66070        -12131
# 2  Indian National Congress   lost  62791 ( -15410)  62791        -15410
# 3               Independent   lost    560 ( -77641)    560        -77641
# 4  Vanchit Bahujan  Aaghadi   lost    558 ( -77643)    558        -77643

# %% [markdown]
# # Who has got most least number of votes

# %%
df.sort_values(by ='Votes',ascending=False).tail(1)
# Out:
#         Constituency                 CandidateName                   Party  \
# 2778  NAGPUR CENTRAL  ADVOCATE SURAJ BALRAM MISHRA  All India Forward Bloc
#
#      Result  Votes_Status  Votes  Votes_Margin
# 2778   lost  26 ( -90534)     26        -90534

# %%
df.sort_values(by ='Votes',ascending = False).head(5)
# Out:
#      Constituency                          CandidateName  \
# 1013    CHINCHWAD               JAGTAP SHANKAR PANDURANG
# 806       BHOSARI             MAHESH (DADA) KISAN LANDGE
# 3235        PARLI              DHANANJAY PANDITRAO MUNDE
# 3733       SHIRUR  DNYANESHWAR  ALIAS  MAULI  ABA  KATKE
# 2561        MAVAL                SUNIL SHANKARRAO SHELKE
#
#                            Party Result       Votes_Status   Votes  \
# 1013      Bharatiya Janata Party    won  235323 (+ 103865)  235323
# 806       Bharatiya Janata Party    won   213624 (+ 63765)  213624
# 3235  Nationalist Congress Party    won  194889 (+ 140224)  194889
# 3733  Nationalist Congress Party    won   192281 (+ 74550)  192281
# 2561  Nationalist Congress Party    won  191255 (+ 108565)  191255
#
#       Votes_Margin
# 1013        103865
# 806          63765
# 3235        140224
# 3733         74550
# 2561        108565

# %%
filt_won = (df['Result']=="won") & (df['Votes_Margin']<500)

# %%
df[filt_won]
# Out:
#           Constituency                          CandidateName  \
# 656            BELAPUR                     MANDA VIJAY MHATRE
# 2455  MALEGAON CENTRAL  MUFTI MOHAMMAD ISMAIL  ABDUL KHALIQUE
# 3543            SAKOLI              NANABHAU FALGUNRAO PATOLE
#
#                                        Party Result    Votes_Status   Votes  \
# 656                   Bharatiya Janata Party    won   91852 (+ 377)   91852
# 2455  All India Majlis-E-Ittehadul Muslimeen    won  109653 (+ 162)  109653
# 3543                Indian National Congress    won   96795 (+ 208)   96795
#
#       Votes_Margin
# 656            377
# 2455           162
# 3543           208

# %%
filt_won = (df['Constituency'] == "MALSHIRAS")

# %%
df[filt_won]
# Out:
#      Constituency                         CandidateName  \
# 2503    MALSHIRAS               UTTAMRAO SHIVDAS JANKAR
# 2504    MALSHIRAS                   RAM VITTHAL SATPUTE
# 2505    MALSHIRAS                  NAMDAS RAMESH ANKUSH
# 2506    MALSHIRAS                    RAJ YASHWANT KUMAR
# 2507    MALSHIRAS             TRIBHUVAN VINAYAK DHAINJE
# 2508    MALSHIRAS                   SURAJ ASHOK SARTAPE
# 2509    MALSHIRAS  SUDHIR ALIAS (YUVRAJ MAMA) ARJUN POL
# 2510    MALSHIRAS                  ARUN MANOHAR DHAINJE
# 2511    MALSHIRAS      PROF. DR.SUNIL SUKHADEV LOKHANDE
# 2512    MALSHIRAS              DADA VISHWANATH LOKHANDE
# 2513    MALSHIRAS         ADV. MANOJKUMAR UTTAM SURWASE
# 2514    MALSHIRAS                   KUMAR ANANDA LONDHE
# 2515    MALSHIRAS                                  NOTA
#
#                                                  Party Result  \
# 2503  Nationalist Congress Party – Sharadchandra Pawar    won
# ...

# %%
filt_lost = (df['Result'] == "lost") & (df['Votes_Margin'] > (-500))

# %%
df[filt_lost]
# Out:
#           Constituency                CandidateName  \
# 657            BELAPUR          SANDEEP GANESH NAIK
# 2456  MALEGAON CENTRAL          ASIF SHAIKH RASHEED
# 3544            SAKOLI  AVINASH ANANDRAO BRAHMANKAR
#
#                                                  Party Result    Votes_Status  \
# 657   Nationalist Congress Party – Sharadchandra Pawar   lost   91475 ( -377)
# 2456    Indian Secular Largest Assembly of Maharashtra   lost  109491 ( -162)
# 3544                            Bharatiya Janata Party   lost   96587 ( -208)
#
#        Votes  Votes_Margin
# 657    91475          -377
# 2456  109491          -162
# 3544   96587          -208

# %% [markdown]
# # Grouping Data

# %%
df.head(5)
# Out:
#   Constituency                                 CandidateName  \
# 0     ACHALPUR                       PRAVIN VASANTRAO TAYADE
# 1     ACHALPUR                                BACCHU B. KADU
# 2     ACHALPUR  ANIRUDHA ALIAS BABALUBHAU SUBHANRAO DESHMUKH
# 3     ACHALPUR                     MANGESH VITTHALRAO BORWAR
# 4     ACHALPUR                        PRADIP SAHEBRAO MANKAR
#
#                       Party Result     Votes_Status  Votes  Votes_Margin
# 0    Bharatiya Janata Party    won  78201 (+ 12131)  78201         12131
# 1    Prahar Janshakti Party   lost  66070 ( -12131)  66070        -12131
# 2  Indian National Congress   lost  62791 ( -15410)  62791        -15410
# 3               Independent   lost    560 ( -77641)    560        -77641
# 4  Vanchit Bahujan  Aaghadi   lost    558 ( -77643)    558        -77643

# %%
group_by_party = df.groupby('Party')

# %%
group_by_party['Party'].count().sort_values(ascending= False).head(20)           # Party counts
# Out:
# Party
# Independent                                         2086
# None of the Above                                    288
# Bahujan Samaj Party                                  237
# Vanchit Bahujan  Aaghadi                             200
# Bharatiya Janata Party                               149
# Maharashtra Navnirman sena                           125
# Indian National Congress                             101
# Shiv Sena (Uddhav Balasaheb Thackeray)                95
# Rashtriya Samaj Paksha                                93
# Nationalist Congress Party – Sharadchandra Pawar      86
# Shiv Sena                                             81
# Nationalist Congress Party                            59
# Peoples Party of India (Democratic)                   44
# Prahar Janshakti Party                                38
# Maharashtra Swarajya party                            32
# Republican Party of India (A)                         31
# ...

# %%
filt_won = (df['Result'] == 'won')

# %%
winning_full_list = df[filt_won]

# %%
winning_full_list
# Out:
#          Constituency                              CandidateName  \
# 0            ACHALPUR                    PRAVIN VASANTRAO TAYADE
# 23              AHERI            ATRAM DHARAMRAOBABA BHAGWANTRAO
# 36           AHMADPUR                   BABASAHEB MOHANRAO PATIL
# 57    AHMEDNAGAR CITY                    SANGRAM ARUNKAKA JAGTAP
# 72             AIROLI                     GANESH RAMCHANDRA NAIK
# ...               ...                                        ...
# 4334           WARORA                       KARAN SANJAY DEOTALE
# 4353           WASHIM                      SHYAM RAMCHARAN KHODE
# 4376            WORLI                    ADITYA UDDHAV THACKERAY
# 4387         YAVATMAL  ANIL ALIAS BALASAHEB SHANKARRAO MANGULKAR
# 4410            YEVLA                            CHHAGAN BHUJBAL
#
#                                        Party Result      Votes_Status   Votes  \
# 0                     Bharatiya Janata Party    won   78201 (+ 12131)   78201
# ...

# %%
filt_won = df['Result'] == "won"

# %%
winning_full_list = df[filt_won]

# %%
winning_full_list
# Out:
#          Constituency                              CandidateName  \
# 0            ACHALPUR                    PRAVIN VASANTRAO TAYADE
# 23              AHERI            ATRAM DHARAMRAOBABA BHAGWANTRAO
# 36           AHMADPUR                   BABASAHEB MOHANRAO PATIL
# 57    AHMEDNAGAR CITY                    SANGRAM ARUNKAKA JAGTAP
# 72             AIROLI                     GANESH RAMCHANDRA NAIK
# ...               ...                                        ...
# 4334           WARORA                       KARAN SANJAY DEOTALE
# 4353           WASHIM                      SHYAM RAMCHARAN KHODE
# 4376            WORLI                    ADITYA UDDHAV THACKERAY
# 4387         YAVATMAL  ANIL ALIAS BALASAHEB SHANKARRAO MANGULKAR
# 4410            YEVLA                            CHHAGAN BHUJBAL
#
#                                        Party Result      Votes_Status   Votes  \
# 0                     Bharatiya Janata Party    won   78201 (+ 12131)   78201
# ...

# %%
filt_lost = df['Result'] == "lost"

# %%
loser_full_list = df[filt_lost]

# %%
loser_full_list
# Out:
#      Constituency                                 CandidateName  \
# 1        ACHALPUR                                BACCHU B. KADU
# 2        ACHALPUR  ANIRUDHA ALIAS BABALUBHAU SUBHANRAO DESHMUKH
# 3        ACHALPUR                     MANGESH VITTHALRAO BORWAR
# 4        ACHALPUR                        PRADIP SAHEBRAO MANKAR
# 5        ACHALPUR                                    RAHUL KADU
# ...           ...                                           ...
# 4418        YEVLA                        JALINDAR DADA KHAIRNAR
# 4419        YEVLA                     SHIVLAL POPATRAO DHANWATE
# 4420        YEVLA                      JITENDRA BHASKAR GAIKWAD
# 4421        YEVLA                 BHAGVATRAO BA. SONAWANE-PATIL
# 4422        YEVLA                           AMOL SURESH GAIKWAD
#
#                                Party Result     Votes_Status  Votes  \
# 1             Prahar Janshakti Party   lost  66070 ( -12131)  66070
# ...

# %%
filter_Malshiras = df['Constituency'] == 'MALSHIRAS'

# %%
df[filter_Malshiras]
# Out:
#      Constituency                         CandidateName  \
# 2503    MALSHIRAS               UTTAMRAO SHIVDAS JANKAR
# 2504    MALSHIRAS                   RAM VITTHAL SATPUTE
# 2505    MALSHIRAS                  NAMDAS RAMESH ANKUSH
# 2506    MALSHIRAS                    RAJ YASHWANT KUMAR
# 2507    MALSHIRAS             TRIBHUVAN VINAYAK DHAINJE
# 2508    MALSHIRAS                   SURAJ ASHOK SARTAPE
# 2509    MALSHIRAS  SUDHIR ALIAS (YUVRAJ MAMA) ARJUN POL
# 2510    MALSHIRAS                  ARUN MANOHAR DHAINJE
# 2511    MALSHIRAS      PROF. DR.SUNIL SUKHADEV LOKHANDE
# 2512    MALSHIRAS              DADA VISHWANATH LOKHANDE
# 2513    MALSHIRAS         ADV. MANOJKUMAR UTTAM SURWASE
# 2514    MALSHIRAS                   KUMAR ANANDA LONDHE
# 2515    MALSHIRAS                                  NOTA
#
#                                                  Party Result  \
# 2503  Nationalist Congress Party – Sharadchandra Pawar    won
# ...

# %%
filter_MNS = df["Party"] == "Maharashtra Navnirman sena"

# %%
df[filter_MNS].head(30)
# Out:
#             Constituency                       CandidateName  \
# 30                 AHERI                 SANDIP MAROTI KORET
# 42              AHMADPUR       DR. NARSINHA UDHAVRAO BHIKANE
# 59       AHMEDNAGAR CITY            SACHIN CHANDRABHAN DAFAL
# 76                AIROLI                BANKHELE NILESH ARUN
# 94              AKKALKOT           MALLINATH SHARNAPPA PATIL
# 153                 AKOT                  CAPT. SUNIL DOBALE
# 190             AMBEGAON                INDORE SUNIL KONDAJI
# 237             AMRAVATI  PAPPU ALIAS MANGESH MADHUKAR PATIL
# 279      ANUSHAKTI NAGAR             ACHARYA NAVIN VIDYADHAR
# 298       ARJUNI MORGAON              BHAVESH UTTAM KUMBHARE
# 357                ASHTI          KAILASH DATTATREYA DAREKAR
# 373   AURANGABAD CENTRAL               DASHRATHE SUHAS ANANT
# 445                 AUSA         NAGRALE SHIVKUMAR GANGADHAR
# 531              BALAPUR               MANGESH GAJANAN GADGE
# ...
